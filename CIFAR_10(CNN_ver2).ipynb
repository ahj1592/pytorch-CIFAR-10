# %% [markdown]
# # Import requirements

# %%
import os
import random
import numpy as np
from tqdm import tqdm

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print(f'Device: {DEVICE}')
# Out:
# Device: cuda

# %% [markdown]
# # Data Augmentation Using `transforms`

# %%
transform_train = transforms.Compose([transforms.Resize((32, 32)),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.RandomRotation(10),
                                      transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
                                      transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                     ])

transform_test = transforms.Compose([transforms.Resize((32, 32)),
                                  transforms.ToTensor(),
                                  transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                 ])

train_dataset = datasets.CIFAR10(root='../data/CIFAR_10',
                                 train=True,
                                 download=True,)
test_dataset = datasets.CIFAR10(root='../data/CIFAR_10',
                                train=False,
                                transform=transform_test)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/CIFAR_10/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=0.0, max=170498071.0), HTML(value='')))
# Extracting ../data/CIFAR_10/cifar-10-python.tar.gz to ../data/CIFAR_10

# %%
for (image, label) in train_dataset:
    image = transforms.ToTensor()(image).unsqueeze_(0)
    print(image.shape)
    print(label)
    break
# Out:
# torch.Size([1, 3, 32, 32])
# 6

# %%
train_list = []
for (image, label) in tqdm(train_dataset):
    img0 = image
    img1 = transforms.RandomHorizontalFlip(1)(image)
    img2 = transforms.RandomRotation(10)(image)
    img3 = transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2))(image)
    img4 = transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2)(image)
    imgs = [img0, img1, img2, img3, img4]
    
    for img in imgs:
        img = transforms.ToTensor()(img).unsqueeze_(0)
        img = transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))(img)
        train_list.append((img, label))

print(f'\n{len(train_list)}')
# Out:
# 100%|██████████| 50000/50000 [01:30<00:00, 550.55it/s]
# 250000

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, data_list):
        self.data = data_list
    
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        image = self.data[idx][0].view(3, 32, 32)
        label = self.data[idx][1]
        return image, label

train_dataset = MyDataset(train_list)

# %%
BATCH_SIZE = 32

train_loader = torch.utils.data.DataLoader(
    dataset=train_dataset, 
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_loader = torch.utils.data.DataLoader(
    dataset=test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

# %% [markdown]
# # Define the Convolution Neural Network (CNN)

# %%
class ConvNet(nn.Module):
    # similar with VGG-16
    def __init__(self):
        super(ConvNet, self).__init__()
        # input shape = (32, 32)
        self.conv = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1, bias=False), # (32, 32)
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1, bias=False), # (32, 32)
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # (16, 16)
            
            nn.Conv2d(64, 128, 3, padding=1, bias=False), # (16, 16)
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding=1, bias=False), # (16, 16)
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # (8, 8)
            
            nn.Conv2d(128, 256, 3, padding=1, bias=False), # (8, 8)
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1, bias=False), # (8, 8)
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1, bias=False), # (8, 8)
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # (4, 4)

            nn.Conv2d(256, 512, 3, padding=1, bias=False), # (4, 4)
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding=1, bias=False), # (4, 4)
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding=1, bias=False), # (4, 4)
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # (2, 2)

            # nn.Conv2d(512, 512, 3, padding=1, bias=False), # (2, 2)
            # nn.BatchNorm2d(512),
            # nn.ReLU(),
            # nn.Conv2d(512, 512, 3, padding=1, bias=False), # (4, 4)
            # nn.BatchNorm2d(512),
            # nn.ReLU(),
            # nn.Conv2d(512, 512, 3, padding=1, bias=False), # (4, 4)
            # nn.BatchNorm2d(512),
            # nn.ReLU(),
            # nn.MaxPool2d(2, 2), # (1, 1)
            
        )


        self.clssify = nn.Sequential(
            nn.Linear(2*2*512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 10),
            nn.LogSoftmax(dim=1),
        )

    def forward(self, x):
        x = self.conv(x)
        x = x.view(-1, 2*2*512)
        x = self.clssify(x)
        return x

# %% [markdown]
# # Define the train, evaluation

# %%
def train(model, train_loader, optimizer, log_interval):
    model.train()
    train_loss = 0
    correct = 0

    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        train_loss += loss.item()
        loss.backward()
        optimizer.step()

        if (batch_idx + 1) % log_interval == 0 or (batch_idx + 1) == len(train_loader):
            pct = 100 * batch_idx / len(train_loader) # percent
            train_loss /= log_interval
            print(f'Train Epoch: {Epoch} [{batch_idx * len(image)}/{len(train_loader.dataset)} ({pct:.0f}%)]\tAverage Train Loss: {train_loss:.6f}')
            train_loss = 0


def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(label.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100 * correct / len(test_loader.dataset)

    return test_loss, test_accuracy

# %% [markdown]
# # set seeds

# %%
def fix_seeds(seed = 42, use_torch=False):
    # fix the seed for reproducibility 
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)

    if use_torch: 
        torch.manual_seed(seed) 
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.deterministic = True

# %%
def init_weights(m):
    # initialize the weight, bias
    if isinstance(m, nn.Conv2d):
        torch.nn.init.kaiming_uniform_(m.weight.data)
        if m.bias is not None:
            torch.nn.init.normal_(m.bias.data)
    elif isinstance(m, nn.BatchNorm2d):
        torch.nn.init.normal_(m.weight.data, mean=1, std=0.02)
        torch.nn.init.constant_(m.bias.data, 0)
    elif isinstance(m, nn.Linear):
        torch.nn.init.kaiming_uniform_(m.weight.data)
        torch.nn.init.normal_(m.bias.data)

# %%
SEED = 42
EPOCHS = 20

fix_seeds(seed=SEED, use_torch=True)
model = ConvNet().to(device=DEVICE)
model.apply(init_weights)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()


for Epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval=1500)
    test_loss, test_acc = evaluate(model, test_loader)
    print(f'\nEpoch: {Epoch}')
    print(f'Average Test Loss: {test_loss:.4f}')
    print(f'Test Accuracy: {test_acc:.2f}\n')
    torch.save(model, f'./models/model_{Epoch:02d}.pt')
# Out:
# Train Epoch: 1 [47968/250000 (19%)]	Average Train Loss: 1.795974
# Train Epoch: 1 [95968/250000 (38%)]	Average Train Loss: 1.248161
# Train Epoch: 1 [143968/250000 (58%)]	Average Train Loss: 0.995478
# Train Epoch: 1 [191968/250000 (77%)]	Average Train Loss: 0.835888
# Train Epoch: 1 [239968/250000 (96%)]	Average Train Loss: 0.723803
# Train Epoch: 1 [124992/250000 (100%)]	Average Train Loss: 0.138366
#
# Epoch: 1
# Average Test Loss: 0.0196
# Test Accuracy: 79.44
#
# Train Epoch: 2 [47968/250000 (19%)]	Average Train Loss: 0.606333
# Train Epoch: 2 [95968/250000 (38%)]	Average Train Loss: 0.553862
# Train Epoch: 2 [143968/250000 (58%)]	Average Train Loss: 0.511143
# Train Epoch: 2 [191968/250000 (77%)]	Average Train Loss: 0.459940
# Train Epoch: 2 [239968/250000 (96%)]	Average Train Loss: 0.428601
# Train Epoch: 2 [124992/250000 (100%)]	Average Train Loss: 0.085365
#
# Epoch: 2
# Average Test Loss: 0.0138
# Test Accuracy: 85.53
#
# Train Epoch: 3 [47968/250000 (19%)]	Average Train Loss: 0.356985
# Train Epoch: 3 [95968/250000 (38%)]	Average Train Loss: 0.339214
# Train Epoch: 3 [143968/250000 (58%)]	Average Train Loss: 0.323027
# Train Epoch: 3 [191968/250000 (77%)]	Average Train Loss: 0.311810
# Train Epoch: 3 [239968/250000 (96%)]	Average Train Loss: 0.286829
# Train Epoch: 3 [124992/250000 (100%)]	Average Train Loss: 0.057619
#
# Epoch: 3
# Average Test Loss: 0.0124
# Test Accuracy: 87.74
#
# Train Epoch: 4 [47968/250000 (19%)]	Average Train Loss: 0.231863
# Train Epoch: 4 [95968/250000 (38%)]	Average Train Loss: 0.226193
# Train Epoch: 4 [143968/250000 (58%)]	Average Train Loss: 0.217492
# Train Epoch: 4 [191968/250000 (77%)]	Average Train Loss: 0.210516
# Train Epoch: 4 [239968/250000 (96%)]	Average Train Loss: 0.199509
# Train Epoch: 4 [124992/250000 (100%)]	Average Train Loss: 0.043362
#
# Epoch: 4
# Average Test Loss: 0.0129
# Test Accuracy: 88.12
#
# Train Epoch: 5 [47968/250000 (19%)]	Average Train Loss: 0.161815
# Train Epoch: 5 [95968/250000 (38%)]	Average Train Loss: 0.157730
# Train Epoch: 5 [143968/250000 (58%)]	Average Train Loss: 0.155307
# Train Epoch: 5 [191968/250000 (77%)]	Average Train Loss: 0.152203
# Train Epoch: 5 [239968/250000 (96%)]	Average Train Loss: 0.152966
# Train Epoch: 5 [124992/250000 (100%)]	Average Train Loss: 0.029829
#
# Epoch: 5
# Average Test Loss: 0.0135
# Test Accuracy: 88.45
#
# Train Epoch: 6 [47968/250000 (19%)]	Average Train Loss: 0.113498
# Train Epoch: 6 [95968/250000 (38%)]	Average Train Loss: 0.113767
# Train Epoch: 6 [143968/250000 (58%)]	Average Train Loss: 0.119597
# Train Epoch: 6 [191968/250000 (77%)]	Average Train Loss: 0.111222
# Train Epoch: 6 [239968/250000 (96%)]	Average Train Loss: 0.119813
# Train Epoch: 6 [124992/250000 (100%)]	Average Train Loss: 0.023176
#
# Epoch: 6
# Average Test Loss: 0.0127
# Test Accuracy: 88.93
#
# Train Epoch: 7 [47968/250000 (19%)]	Average Train Loss: 0.088807
# Train Epoch: 7 [95968/250000 (38%)]	Average Train Loss: 0.093448
# Train Epoch: 7 [143968/250000 (58%)]	Average Train Loss: 0.089615
# Train Epoch: 7 [191968/250000 (77%)]	Average Train Loss: 0.095359
# Train Epoch: 7 [239968/250000 (96%)]	Average Train Loss: 0.099497
# Train Epoch: 7 [124992/250000 (100%)]	Average Train Loss: 0.018272
#
# Epoch: 7
# Average Test Loss: 0.0149
# Test Accuracy: 89.05
#
# Train Epoch: 8 [47968/250000 (19%)]	Average Train Loss: 0.067940
# Train Epoch: 8 [95968/250000 (38%)]	Average Train Loss: 0.080829
# Train Epoch: 8 [143968/250000 (58%)]	Average Train Loss: 0.073364
# Train Epoch: 8 [191968/250000 (77%)]	Average Train Loss: 0.084504
# Train Epoch: 8 [239968/250000 (96%)]	Average Train Loss: 0.074254
# Train Epoch: 8 [124992/250000 (100%)]	Average Train Loss: 0.016979
#
# Epoch: 8
# Average Test Loss: 0.0137
# Test Accuracy: 89.12
#
# Train Epoch: 9 [47968/250000 (19%)]	Average Train Loss: 0.060265
# Train Epoch: 9 [95968/250000 (38%)]	Average Train Loss: 0.064152
# Train Epoch: 9 [143968/250000 (58%)]	Average Train Loss: 0.067630
# Train Epoch: 9 [191968/250000 (77%)]	Average Train Loss: 0.068070
# Train Epoch: 9 [239968/250000 (96%)]	Average Train Loss: 0.069810
# Train Epoch: 9 [124992/250000 (100%)]	Average Train Loss: 0.015110
#
# Epoch: 9
# Average Test Loss: 0.0139
# Test Accuracy: 88.57
#
# Train Epoch: 10 [47968/250000 (19%)]	Average Train Loss: 0.051734
# Train Epoch: 10 [95968/250000 (38%)]	Average Train Loss: 0.055423
# Train Epoch: 10 [143968/250000 (58%)]	Average Train Loss: 0.058950
# Train Epoch: 10 [191968/250000 (77%)]	Average Train Loss: 0.062019
# Train Epoch: 10 [239968/250000 (96%)]	Average Train Loss: 0.055695
# Train Epoch: 10 [124992/250000 (100%)]	Average Train Loss: 0.013732
#
# Epoch: 10
# Average Test Loss: 0.0163
# Test Accuracy: 88.79
#
# Train Epoch: 11 [47968/250000 (19%)]	Average Train Loss: 0.045884
# Train Epoch: 11 [95968/250000 (38%)]	Average Train Loss: 0.051471
# Train Epoch: 11 [143968/250000 (58%)]	Average Train Loss: 0.052836
# Train Epoch: 11 [191968/250000 (77%)]	Average Train Loss: 0.053553
# Train Epoch: 11 [239968/250000 (96%)]	Average Train Loss: 0.056498
# Train Epoch: 11 [124992/250000 (100%)]	Average Train Loss: 0.012868
#
# Epoch: 11
# Average Test Loss: 0.0167
# Test Accuracy: 89.45
#
# Train Epoch: 12 [47968/250000 (19%)]	Average Train Loss: 0.043202
# Train Epoch: 12 [95968/250000 (38%)]	Average Train Loss: 0.041687
# Train Epoch: 12 [143968/250000 (58%)]	Average Train Loss: 0.048018
# Train Epoch: 12 [191968/250000 (77%)]	Average Train Loss: 0.049441
# Train Epoch: 12 [239968/250000 (96%)]	Average Train Loss: 0.046088
# Train Epoch: 12 [124992/250000 (100%)]	Average Train Loss: 0.009691
#
# Epoch: 12
# Average Test Loss: 0.0157
# Test Accuracy: 89.03
#
# Train Epoch: 13 [47968/250000 (19%)]	Average Train Loss: 0.043663
# Train Epoch: 13 [95968/250000 (38%)]	Average Train Loss: 0.043148
# Train Epoch: 13 [143968/250000 (58%)]	Average Train Loss: 0.041874
# Train Epoch: 13 [191968/250000 (77%)]	Average Train Loss: 0.043302
# Train Epoch: 13 [239968/250000 (96%)]	Average Train Loss: 0.042581
# Train Epoch: 13 [124992/250000 (100%)]	Average Train Loss: 0.009460
#
# Epoch: 13
# Average Test Loss: 0.0164
# Test Accuracy: 89.14
#
# Train Epoch: 14 [47968/250000 (19%)]	Average Train Loss: 0.036734
# Train Epoch: 14 [95968/250000 (38%)]	Average Train Loss: 0.041989
# Train Epoch: 14 [143968/250000 (58%)]	Average Train Loss: 0.042066
# Train Epoch: 14 [191968/250000 (77%)]	Average Train Loss: 0.041290
# Train Epoch: 14 [239968/250000 (96%)]	Average Train Loss: 0.040272
# Train Epoch: 14 [124992/250000 (100%)]	Average Train Loss: 0.008261
#
# Epoch: 14
# Average Test Loss: 0.0174
# Test Accuracy: 89.63
#
# Train Epoch: 15 [47968/250000 (19%)]	Average Train Loss: 0.034146
# Train Epoch: 15 [95968/250000 (38%)]	Average Train Loss: 0.036745
# Train Epoch: 15 [143968/250000 (58%)]	Average Train Loss: 0.039033
# Train Epoch: 15 [191968/250000 (77%)]	Average Train Loss: 0.035847
# Train Epoch: 15 [239968/250000 (96%)]	Average Train Loss: 0.037417
# Train Epoch: 15 [124992/250000 (100%)]	Average Train Loss: 0.009256
#
# Epoch: 15
# Average Test Loss: 0.0183
# Test Accuracy: 89.57
#
# Train Epoch: 16 [47968/250000 (19%)]	Average Train Loss: 0.035455
# Train Epoch: 16 [95968/250000 (38%)]	Average Train Loss: 0.036393
# Train Epoch: 16 [143968/250000 (58%)]	Average Train Loss: 0.031607
# Train Epoch: 16 [191968/250000 (77%)]	Average Train Loss: 0.040132
# Train Epoch: 16 [239968/250000 (96%)]	Average Train Loss: 0.040504
# Train Epoch: 16 [124992/250000 (100%)]	Average Train Loss: 0.008140
#
# Epoch: 16
# Average Test Loss: 0.0172
# Test Accuracy: 89.45
#
# Train Epoch: 17 [47968/250000 (19%)]	Average Train Loss: 0.021404
# Train Epoch: 17 [95968/250000 (38%)]	Average Train Loss: 0.034282
# Train Epoch: 17 [143968/250000 (58%)]	Average Train Loss: 0.035534
# Train Epoch: 17 [191968/250000 (77%)]	Average Train Loss: 0.031364
# Train Epoch: 17 [239968/250000 (96%)]	Average Train Loss: 0.034632
# Train Epoch: 17 [124992/250000 (100%)]	Average Train Loss: 0.005757
#
# Epoch: 17
# Average Test Loss: 0.0186
# Test Accuracy: 89.37
#
# Train Epoch: 18 [47968/250000 (19%)]	Average Train Loss: 0.025702
# Train Epoch: 18 [95968/250000 (38%)]	Average Train Loss: 0.032729
# Train Epoch: 18 [143968/250000 (58%)]	Average Train Loss: 0.029701
# Train Epoch: 18 [191968/250000 (77%)]	Average Train Loss: 0.035439
# Train Epoch: 18 [239968/250000 (96%)]	Average Train Loss: 0.034508
# Train Epoch: 18 [124992/250000 (100%)]	Average Train Loss: 0.007563
#
# Epoch: 18
# Average Test Loss: 0.0206
# Test Accuracy: 89.34
#
# Train Epoch: 19 [47968/250000 (19%)]	Average Train Loss: 0.028907
# Train Epoch: 19 [95968/250000 (38%)]	Average Train Loss: 0.028558
# Train Epoch: 19 [143968/250000 (58%)]	Average Train Loss: 0.028074
# Train Epoch: 19 [191968/250000 (77%)]	Average Train Loss: 0.032071
# Train Epoch: 19 [239968/250000 (96%)]	Average Train Loss: 0.029476
# Train Epoch: 19 [124992/250000 (100%)]	Average Train Loss: 0.005814
#
# Epoch: 19
# Average Test Loss: 0.0188
# Test Accuracy: 89.54
#
# Train Epoch: 20 [47968/250000 (19%)]	Average Train Loss: 0.030389
# Train Epoch: 20 [95968/250000 (38%)]	Average Train Loss: 0.025143
# Train Epoch: 20 [143968/250000 (58%)]	Average Train Loss: 0.028755
# Train Epoch: 20 [191968/250000 (77%)]	Average Train Loss: 0.030757
# Train Epoch: 20 [239968/250000 (96%)]	Average Train Loss: 0.028215
# Train Epoch: 20 [124992/250000 (100%)]	Average Train Loss: 0.005672
#
# Epoch: 20
# Average Test Loss: 0.0219
# Test Accuracy: 89.81

# %%
model = torch.load(f'./models/model_20.pt')
for Epoch in range(21, 51):
    train(model, train_loader, optimizer, log_interval=1500)
    test_loss, test_acc = evaluate(model, test_loader)
    print(f'\nEpoch: {Epoch}')
    print(f'Average Test Loss: {test_loss:.4f}')
    print(f'Test Accuracy: {test_acc:.2f}\n')
    torch.save(model, f'./models/model_{Epoch:02d}.pt')
# Out:
# Train Epoch: 21 [47968/250000 (19%)]	Average Train Loss: 0.022305
# Train Epoch: 21 [95968/250000 (38%)]	Average Train Loss: 0.019942
# Train Epoch: 21 [143968/250000 (58%)]	Average Train Loss: 0.020935
# Train Epoch: 21 [191968/250000 (77%)]	Average Train Loss: 0.020250
# Train Epoch: 21 [239968/250000 (96%)]	Average Train Loss: 0.020705
# Train Epoch: 21 [124992/250000 (100%)]	Average Train Loss: 0.004223
#
# Epoch: 21
# Average Test Loss: 0.0214
# Test Accuracy: 89.91
#
# Train Epoch: 22 [47968/250000 (19%)]	Average Train Loss: 0.022674
# Train Epoch: 22 [95968/250000 (38%)]	Average Train Loss: 0.020973
# Train Epoch: 22 [143968/250000 (58%)]	Average Train Loss: 0.019665
# Train Epoch: 22 [191968/250000 (77%)]	Average Train Loss: 0.019950
# Train Epoch: 22 [239968/250000 (96%)]	Average Train Loss: 0.018924
# Train Epoch: 22 [124992/250000 (100%)]	Average Train Loss: 0.004508
#
# Epoch: 22
# Average Test Loss: 0.0217
# Test Accuracy: 89.89
#
# Train Epoch: 23 [47968/250000 (19%)]	Average Train Loss: 0.022718
# Train Epoch: 23 [95968/250000 (38%)]	Average Train Loss: 0.018412
# Train Epoch: 23 [143968/250000 (58%)]	Average Train Loss: 0.019986
# Train Epoch: 23 [191968/250000 (77%)]	Average Train Loss: 0.018636
# Train Epoch: 23 [239968/250000 (96%)]	Average Train Loss: 0.017928
# Train Epoch: 23 [124992/250000 (100%)]	Average Train Loss: 0.003760
#
# Epoch: 23
# Average Test Loss: 0.0214
# Test Accuracy: 89.93
#
# Train Epoch: 24 [47968/250000 (19%)]	Average Train Loss: 0.021939
# Train Epoch: 24 [95968/250000 (38%)]	Average Train Loss: 0.019662
# Train Epoch: 24 [143968/250000 (58%)]	Average Train Loss: 0.019839
# Train Epoch: 24 [191968/250000 (77%)]	Average Train Loss: 0.019583
# Train Epoch: 24 [239968/250000 (96%)]	Average Train Loss: 0.018566
# Train Epoch: 24 [124992/250000 (100%)]	Average Train Loss: 0.005296
#
# Epoch: 24
# Average Test Loss: 0.0214
# Test Accuracy: 90.00
#
# Train Epoch: 25 [47968/250000 (19%)]	Average Train Loss: 0.018709
# Train Epoch: 25 [95968/250000 (38%)]	Average Train Loss: 0.021654
# Train Epoch: 25 [143968/250000 (58%)]	Average Train Loss: 0.020077
# Train Epoch: 25 [191968/250000 (77%)]	Average Train Loss: 0.023346
# Train Epoch: 25 [239968/250000 (96%)]	Average Train Loss: 0.022772
# Train Epoch: 25 [124992/250000 (100%)]	Average Train Loss: 0.004266
#
# Epoch: 25
# Average Test Loss: 0.0213
# Test Accuracy: 89.96
#
# Train Epoch: 26 [47968/250000 (19%)]	Average Train Loss: 0.021527
# Train Epoch: 26 [95968/250000 (38%)]	Average Train Loss: 0.020470
# Train Epoch: 26 [143968/250000 (58%)]	Average Train Loss: 0.020988
# Train Epoch: 26 [191968/250000 (77%)]	Average Train Loss: 0.018759
# Train Epoch: 26 [239968/250000 (96%)]	Average Train Loss: 0.019238
# Train Epoch: 26 [124992/250000 (100%)]	Average Train Loss: 0.003234
#
# Epoch: 26
# Average Test Loss: 0.0222
# Test Accuracy: 89.92
#
# Train Epoch: 27 [47968/250000 (19%)]	Average Train Loss: 0.020228
# Train Epoch: 27 [95968/250000 (38%)]	Average Train Loss: 0.018238
# Train Epoch: 27 [143968/250000 (58%)]	Average Train Loss: 0.024546
# Train Epoch: 27 [191968/250000 (77%)]	Average Train Loss: 0.022045
# Train Epoch: 27 [239968/250000 (96%)]	Average Train Loss: 0.019279
# Train Epoch: 27 [124992/250000 (100%)]	Average Train Loss: 0.003379
#
# Epoch: 27
# Average Test Loss: 0.0217
# Test Accuracy: 89.87
#
# Train Epoch: 28 [47968/250000 (19%)]	Average Train Loss: 0.019053
# Train Epoch: 28 [95968/250000 (38%)]	Average Train Loss: 0.020514
# Train Epoch: 28 [143968/250000 (58%)]	Average Train Loss: 0.019941
# Train Epoch: 28 [191968/250000 (77%)]	Average Train Loss: 0.020358
# Train Epoch: 28 [239968/250000 (96%)]	Average Train Loss: 0.019068
# Train Epoch: 28 [124992/250000 (100%)]	Average Train Loss: 0.006005
#
# Epoch: 28
# Average Test Loss: 0.0213
# Test Accuracy: 89.76
#
# Train Epoch: 29 [47968/250000 (19%)]	Average Train Loss: 0.019807
# Train Epoch: 29 [95968/250000 (38%)]	Average Train Loss: 0.020432
# Train Epoch: 29 [143968/250000 (58%)]	Average Train Loss: 0.018912
# Train Epoch: 29 [191968/250000 (77%)]	Average Train Loss: 0.018243
# Train Epoch: 29 [239968/250000 (96%)]	Average Train Loss: 0.020857
# Train Epoch: 29 [124992/250000 (100%)]	Average Train Loss: 0.004606
#
# Epoch: 29
# Average Test Loss: 0.0215
# Test Accuracy: 89.96
#
# Train Epoch: 30 [47968/250000 (19%)]	Average Train Loss: 0.022168
# Train Epoch: 30 [95968/250000 (38%)]	Average Train Loss: 0.018225
# Train Epoch: 30 [143968/250000 (58%)]	Average Train Loss: 0.018418
# Train Epoch: 30 [191968/250000 (77%)]	Average Train Loss: 0.021428
# Train Epoch: 30 [239968/250000 (96%)]	Average Train Loss: 0.019329
# Train Epoch: 30 [124992/250000 (100%)]	Average Train Loss: 0.004146
#
# Epoch: 30
# Average Test Loss: 0.0219
# Test Accuracy: 89.88
#
# Train Epoch: 31 [47968/250000 (19%)]	Average Train Loss: 0.021010
# Train Epoch: 31 [95968/250000 (38%)]	Average Train Loss: 0.019526
# Train Epoch: 31 [143968/250000 (58%)]	Average Train Loss: 0.019140
# Train Epoch: 31 [191968/250000 (77%)]	Average Train Loss: 0.019481
# Train Epoch: 31 [239968/250000 (96%)]	Average Train Loss: 0.021909
# Train Epoch: 31 [124992/250000 (100%)]	Average Train Loss: 0.004178
#
# Epoch: 31
# Average Test Loss: 0.0217
# Test Accuracy: 89.86
#
# Train Epoch: 32 [47968/250000 (19%)]	Average Train Loss: 0.019480
# Train Epoch: 32 [95968/250000 (38%)]	Average Train Loss: 0.023252
# Train Epoch: 32 [143968/250000 (58%)]	Average Train Loss: 0.022398
# Train Epoch: 32 [191968/250000 (77%)]	Average Train Loss: 0.019742
# Train Epoch: 32 [239968/250000 (96%)]	Average Train Loss: 0.019738
# Train Epoch: 32 [124992/250000 (100%)]	Average Train Loss: 0.004036
#
# Epoch: 32
# Average Test Loss: 0.0217
# Test Accuracy: 89.91
#
# Train Epoch: 33 [47968/250000 (19%)]	Average Train Loss: 0.019710
# Train Epoch: 33 [95968/250000 (38%)]	Average Train Loss: 0.021259
# Train Epoch: 33 [143968/250000 (58%)]	Average Train Loss: 0.019692
# Train Epoch: 33 [191968/250000 (77%)]	Average Train Loss: 0.019692
# Train Epoch: 33 [239968/250000 (96%)]	Average Train Loss: 0.021771
# Train Epoch: 33 [124992/250000 (100%)]	Average Train Loss: 0.002678
#
# Epoch: 33
# Average Test Loss: 0.0218
# Test Accuracy: 89.91
#
# Train Epoch: 34 [47968/250000 (19%)]	Average Train Loss: 0.017444
# Train Epoch: 34 [95968/250000 (38%)]	Average Train Loss: 0.020925
# Train Epoch: 34 [143968/250000 (58%)]	Average Train Loss: 0.021627
# Train Epoch: 34 [191968/250000 (77%)]	Average Train Loss: 0.018022
# Train Epoch: 34 [239968/250000 (96%)]	Average Train Loss: 0.018784
# Train Epoch: 34 [124992/250000 (100%)]	Average Train Loss: 0.004210
#
# Epoch: 34
# Average Test Loss: 0.0223
# Test Accuracy: 89.98
#
# Train Epoch: 35 [47968/250000 (19%)]	Average Train Loss: 0.018608
# Train Epoch: 35 [95968/250000 (38%)]	Average Train Loss: 0.021410
# Train Epoch: 35 [143968/250000 (58%)]	Average Train Loss: 0.020839
# Train Epoch: 35 [191968/250000 (77%)]	Average Train Loss: 0.020135
# Train Epoch: 35 [239968/250000 (96%)]	Average Train Loss: 0.020644
# Train Epoch: 35 [124992/250000 (100%)]	Average Train Loss: 0.004248
#
# Epoch: 35
# Average Test Loss: 0.0213
# Test Accuracy: 89.91
#
# Train Epoch: 36 [47968/250000 (19%)]	Average Train Loss: 0.020350
# Train Epoch: 36 [95968/250000 (38%)]	Average Train Loss: 0.019398
# Train Epoch: 36 [143968/250000 (58%)]	Average Train Loss: 0.021011
# Train Epoch: 36 [191968/250000 (77%)]	Average Train Loss: 0.020710
# Train Epoch: 36 [239968/250000 (96%)]	Average Train Loss: 0.020493
# Train Epoch: 36 [124992/250000 (100%)]	Average Train Loss: 0.004751
#
# Epoch: 36
# Average Test Loss: 0.0219
# Test Accuracy: 90.00
#
# Train Epoch: 37 [47968/250000 (19%)]	Average Train Loss: 0.019297
# Train Epoch: 37 [95968/250000 (38%)]	Average Train Loss: 0.023557
# Train Epoch: 37 [143968/250000 (58%)]	Average Train Loss: 0.021122
# Train Epoch: 37 [191968/250000 (77%)]	Average Train Loss: 0.021407
# Train Epoch: 37 [239968/250000 (96%)]	Average Train Loss: 0.019139
# Train Epoch: 37 [124992/250000 (100%)]	Average Train Loss: 0.003983
#
# Epoch: 37
# Average Test Loss: 0.0217
# Test Accuracy: 89.94
#
# Train Epoch: 38 [47968/250000 (19%)]	Average Train Loss: 0.021467
# Train Epoch: 38 [95968/250000 (38%)]	Average Train Loss: 0.018383
# Train Epoch: 38 [143968/250000 (58%)]	Average Train Loss: 0.021559
# Train Epoch: 38 [191968/250000 (77%)]	Average Train Loss: 0.019352
# Train Epoch: 38 [239968/250000 (96%)]	Average Train Loss: 0.019068
# Train Epoch: 38 [124992/250000 (100%)]	Average Train Loss: 0.005383
#
# Epoch: 38
# Average Test Loss: 0.0216
# Test Accuracy: 90.02
#
# Train Epoch: 39 [47968/250000 (19%)]	Average Train Loss: 0.018513
# Train Epoch: 39 [95968/250000 (38%)]	Average Train Loss: 0.019355
# Train Epoch: 39 [143968/250000 (58%)]	Average Train Loss: 0.019708
# Train Epoch: 39 [191968/250000 (77%)]	Average Train Loss: 0.019851
# Train Epoch: 39 [239968/250000 (96%)]	Average Train Loss: 0.020144

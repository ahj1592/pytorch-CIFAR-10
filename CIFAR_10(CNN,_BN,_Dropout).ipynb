# %% [markdown]
# # Import requirements

# %%
import os
import random
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')
print(f'Device: {DEVICE}')
# Out:
# Device: cuda

# %% [markdown]
# # Data Augmentation Using `transforms`

# %%
transform_train = transforms.Compose([transforms.Resize((32, 32)),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.RandomRotation(10),
                                      transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
                                      transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
                                      transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                     ])

transform_test = transforms.Compose([transforms.Resize((32, 32)),
                                  transforms.ToTensor(),
                                  transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                 ])

train_dataset = datasets.CIFAR10(root='../data/CIFAR_10',
                                 train=True,
                                 download=True,
                                 transform=transform_train)
test_dataset = datasets.CIFAR10(root='../data/CIFAR_10',
                                train=False,
                                transform=transform_test)
# Out:
# Files already downloaded and verified

# %%
BATCH_SIZE = 32

train_loader = torch.utils.data.DataLoader(
    dataset=train_dataset, 
    batch_size=BATCH_SIZE,
    shuffle=True
)

test_loader = torch.utils.data.DataLoader(
    dataset=test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

# %% [markdown]
# # Check Shape of Images

# %%
for (input, label) in train_loader:
    print(input.shape)
    break
# Out:
# torch.Size([32, 3, 32, 32])

# %% [markdown]
# # Define the Convolution Neural Network (CNN)

# %%
class ConvNet(nn.Module):
    # similar with VGG-16
    def __init__(self):
        super(ConvNet, self).__init__()
        # input shape = (32, 32)
        self.conv = nn.Sequential(
            nn.Conv2d(3, 64, 3, padding=1, bias=False), # (32, 32)
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, padding=1, bias=False), # (32, 32)
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # (16, 16)
            
            nn.Conv2d(64, 128, 3, padding=1, bias=False), # (16, 16)
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 128, 3, padding=1, bias=False), # (16, 16)
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # (8, 8)
            
            nn.Conv2d(128, 256, 3, padding=1, bias=False), # (8, 8)
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1, bias=False), # (8, 8)
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, 3, padding=1, bias=False), # (8, 8)
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # (4, 4)

            nn.Conv2d(256, 512, 3, padding=1, bias=False), # (4, 4)
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding=1, bias=False), # (4, 4)
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding=1, bias=False), # (4, 4)
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # (2, 2)

            nn.Conv2d(512, 512, 3, padding=1, bias=False), # (2, 2)
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding=1, bias=False), # (4, 4)
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.Conv2d(512, 512, 3, padding=1, bias=False), # (4, 4)
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2, 2), # (1, 1)
            
        )


        self.clssify = nn.Sequential(
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(128, 10),
            nn.LogSoftmax(dim=1),
        )

    def forward(self, x):
        x = self.conv(x)
        x = x.view(-1, 512)
        x = self.clssify(x)
        return x

# %% [markdown]
# # Define the train, evaluation

# %%
def train(model, train_loader, optimizer, log_interval):
    model.train()
    
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            pct = 100 * batch_idx / len(train_loader) # percent
            train_loss = loss.item()
            print(f'Train Epoch: {Epoch} [{batch_idx * len(image)}/{len(train_loader.dataset)} ({pct:.0f}%)]\tTrain Loss: {train_loss:.6f}')


def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(label.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    test_accuracy = 100 * correct / len(test_loader.dataset)

    return test_loss, test_accuracy

# %% [markdown]
# # set seeds

# %%
def fix_seeds(seed = 42, use_torch=False):
    # fix the seed for reproducibility 
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)

    if use_torch: 
        torch.manual_seed(seed) 
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.deterministic = True

# %%
def init_weights(m):
    # initialize the weight, bias
    if isinstance(m, nn.Conv2d):
        torch.nn.init.kaiming_uniform_(m.weight.data)
        if m.bias is not None:
            torch.nn.init.normal_(m.bias.data)
    elif isinstance(m, nn.BatchNorm2d):
        torch.nn.init.normal_(m.weight.data, mean=1, std=0.02)
        torch.nn.init.constant_(m.bias.data, 0)
    elif isinstance(m, nn.Linear):
        torch.nn.init.kaiming_uniform_(m.weight.data)
        torch.nn.init.normal_(m.bias.data)

# %%
SEED = 42
EPOCHS = 50

fix_seeds(seed=SEED, use_torch=True)
model = ConvNet().to(device=DEVICE)
model.apply(init_weights)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()


for Epoch in range(1, EPOCHS + 1):
    train_acc = train(model, train_loader, optimizer, log_interval=200)
    test_loss, test_acc = evaluate(model, test_loader)
    print(f'\nEpoch: {Epoch}')
    print(f'Test Loss: {test_loss:.4f}')
    print(f'Test Accuracy: {test_acc:.2f}\n')
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Train Loss: 3.905370
# Train Epoch: 1 [6400/50000 (13%)]	Train Loss: 2.054904
# Train Epoch: 1 [12800/50000 (26%)]	Train Loss: 2.287699
# Train Epoch: 1 [19200/50000 (38%)]	Train Loss: 2.012368
# Train Epoch: 1 [25600/50000 (51%)]	Train Loss: 1.856004
# Train Epoch: 1 [32000/50000 (64%)]	Train Loss: 1.803567
# Train Epoch: 1 [38400/50000 (77%)]	Train Loss: 2.103170
# Train Epoch: 1 [44800/50000 (90%)]	Train Loss: 1.778265
#
# Epoch: 1
# Test Loss: 0.0514
# Test Accuracy: 37.26
#
# Train Epoch: 2 [0/50000 (0%)]	Train Loss: 1.476891
# Train Epoch: 2 [6400/50000 (13%)]	Train Loss: 1.641209
# Train Epoch: 2 [12800/50000 (26%)]	Train Loss: 1.601245
# Train Epoch: 2 [19200/50000 (38%)]	Train Loss: 1.776516
# Train Epoch: 2 [25600/50000 (51%)]	Train Loss: 1.636301
# Train Epoch: 2 [32000/50000 (64%)]	Train Loss: 1.465481
# Train Epoch: 2 [38400/50000 (77%)]	Train Loss: 1.490489
# Train Epoch: 2 [44800/50000 (90%)]	Train Loss: 1.546280
#
# Epoch: 2
# Test Loss: 0.0397
# Test Accuracy: 52.40
#
# Train Epoch: 3 [0/50000 (0%)]	Train Loss: 1.484950
# Train Epoch: 3 [6400/50000 (13%)]	Train Loss: 1.259748
# Train Epoch: 3 [12800/50000 (26%)]	Train Loss: 1.171716
# Train Epoch: 3 [19200/50000 (38%)]	Train Loss: 1.314597
# Train Epoch: 3 [25600/50000 (51%)]	Train Loss: 1.463686
# Train Epoch: 3 [32000/50000 (64%)]	Train Loss: 1.508883
# Train Epoch: 3 [38400/50000 (77%)]	Train Loss: 1.487761
# Train Epoch: 3 [44800/50000 (90%)]	Train Loss: 1.426164
#
# Epoch: 3
# Test Loss: 0.0345
# Test Accuracy: 60.02
#
# Train Epoch: 4 [0/50000 (0%)]	Train Loss: 1.033797
# Train Epoch: 4 [6400/50000 (13%)]	Train Loss: 1.210844
# Train Epoch: 4 [12800/50000 (26%)]	Train Loss: 1.151141
# Train Epoch: 4 [19200/50000 (38%)]	Train Loss: 0.931778
# Train Epoch: 4 [25600/50000 (51%)]	Train Loss: 1.241750
# Train Epoch: 23 [6400/50000 (13%)]	Train Loss: 0.399797
# Train Epoch: 23 [12800/50000 (26%)]	Train Loss: 0.671856
# Train Epoch: 23 [19200/50000 (38%)]	Train Loss: 0.236084
# Train Epoch: 23 [25600/50000 (51%)]	Train Loss: 0.188946
# Train Epoch: 23 [32000/50000 (64%)]	Train Loss: 0.376424
# Train Epoch: 23 [38400/50000 (77%)]	Train Loss: 0.162142
# Train Epoch: 23 [44800/50000 (90%)]	Train Loss: 0.353400
#
# Epoch: 23
# Test Loss: 0.0115
# Test Accuracy: 88.32
#
# Train Epoch: 24 [0/50000 (0%)]	Train Loss: 0.422931
# Train Epoch: 24 [6400/50000 (13%)]	Train Loss: 0.287249
# Train Epoch: 24 [12800/50000 (26%)]	Train Loss: 0.629943
# Train Epoch: 24 [19200/50000 (38%)]	Train Loss: 0.237487
# Train Epoch: 24 [25600/50000 (51%)]	Train Loss: 0.366397
# Train Epoch: 24 [32000/50000 (64%)]	Train Loss: 0.183710
# Train Epoch: 24 [38400/50000 (77%)]	Train Loss: 0.211721
# Train Epoch: 24 [44800/50000 (90%)]	Train Loss: 0.470972
#
# Epoch: 24
# Test Loss: 0.0116
# Test Accuracy: 88.65
#
# Train Epoch: 25 [0/50000 (0%)]	Train Loss: 0.203342
# Train Epoch: 25 [6400/50000 (13%)]	Train Loss: 0.334460
# Train Epoch: 25 [12800/50000 (26%)]	Train Loss: 0.243806
# Train Epoch: 25 [19200/50000 (38%)]	Train Loss: 0.582885
# Train Epoch: 25 [25600/50000 (51%)]	Train Loss: 0.261796
# Train Epoch: 25 [32000/50000 (64%)]	Train Loss: 0.331930
# Train Epoch: 25 [38400/50000 (77%)]	Train Loss: 0.393760
# Train Epoch: 25 [44800/50000 (90%)]	Train Loss: 0.676481
#
# Epoch: 25
# Test Loss: 0.0119
# Test Accuracy: 87.73
#
# Train Epoch: 26 [0/50000 (0%)]	Train Loss: 0.415545
# Train Epoch: 26 [6400/50000 (13%)]	Train Loss: 0.305182
# Train Epoch: 26 [12800/50000 (26%)]	Train Loss: 0.272104
# Train Epoch: 26 [19200/50000 (38%)]	Train Loss: 0.267971
# Train Epoch: 26 [25600/50000 (51%)]	Train Loss: 0.415415
# Train Epoch: 26 [32000/50000 (64%)]	Train Loss: 0.209209
# Train Epoch: 26 [38400/50000 (77%)]	Train Loss: 0.775172
# Train Epoch: 26 [44800/50000 (90%)]	Train Loss: 0.394376
#
# Epoch: 26
# Test Loss: 0.0110
# Test Accuracy: 88.60
#
# Train Epoch: 27 [0/50000 (0%)]	Train Loss: 0.241582
# Train Epoch: 27 [6400/50000 (13%)]	Train Loss: 0.400202
# Train Epoch: 27 [12800/50000 (26%)]	Train Loss: 0.216612
# Train Epoch: 27 [19200/50000 (38%)]	Train Loss: 0.262701
# Train Epoch: 27 [25600/50000 (51%)]	Train Loss: 0.272232
# Train Epoch: 27 [32000/50000 (64%)]	Train Loss: 0.286761
# Train Epoch: 27 [38400/50000 (77%)]	Train Loss: 0.216684
# Train Epoch: 27 [44800/50000 (90%)]	Train Loss: 0.124366
#
# Epoch: 27
# Test Loss: 0.0110
# Test Accuracy: 88.43
#
# Train Epoch: 28 [0/50000 (0%)]	Train Loss: 0.203070
# Train Epoch: 28 [6400/50000 (13%)]	Train Loss: 0.201383
# Train Epoch: 28 [12800/50000 (26%)]	Train Loss: 0.171910
# Train Epoch: 28 [19200/50000 (38%)]	Train Loss: 0.269675
# Train Epoch: 28 [25600/50000 (51%)]	Train Loss: 0.698014
# Train Epoch: 28 [32000/50000 (64%)]	Train Loss: 0.689249
# Train Epoch: 28 [38400/50000 (77%)]	Train Loss: 0.148811
# Train Epoch: 28 [44800/50000 (90%)]	Train Loss: 0.196914
#
# Epoch: 28
# Test Loss: 0.0109
# Test Accuracy: 89.12
#
# Train Epoch: 29 [0/50000 (0%)]	Train Loss: 0.235179
# Train Epoch: 29 [6400/50000 (13%)]	Train Loss: 0.381533
# Train Epoch: 29 [12800/50000 (26%)]	Train Loss: 0.199970
# Train Epoch: 29 [19200/50000 (38%)]	Train Loss: 0.482108
# Train Epoch: 29 [25600/50000 (51%)]	Train Loss: 0.393046
# Train Epoch: 29 [32000/50000 (64%)]	Train Loss: 0.066600
# Train Epoch: 29 [38400/50000 (77%)]	Train Loss: 0.643867
# Train Epoch: 29 [44800/50000 (90%)]	Train Loss: 0.386410
#
# Epoch: 29
# Test Loss: 0.0120
# Test Accuracy: 88.20
#
# Train Epoch: 30 [0/50000 (0%)]	Train Loss: 0.079236
# Train Epoch: 30 [6400/50000 (13%)]	Train Loss: 0.491826
# Train Epoch: 30 [12800/50000 (26%)]	Train Loss: 0.465090
# Train Epoch: 30 [19200/50000 (38%)]	Train Loss: 0.186474
# Train Epoch: 30 [25600/50000 (51%)]	Train Loss: 0.282549
# Train Epoch: 30 [32000/50000 (64%)]	Train Loss: 0.335509
# Train Epoch: 30 [38400/50000 (77%)]	Train Loss: 0.308192
# Train Epoch: 30 [44800/50000 (90%)]	Train Loss: 0.279019
#
# Epoch: 30
# Test Loss: 0.0110
# Test Accuracy: 88.87
#
# Train Epoch: 31 [0/50000 (0%)]	Train Loss: 0.117022
# Train Epoch: 31 [6400/50000 (13%)]	Train Loss: 0.132427
# Train Epoch: 31 [12800/50000 (26%)]	Train Loss: 0.398661
# Train Epoch: 31 [19200/50000 (38%)]	Train Loss: 0.504104
# Train Epoch: 31 [25600/50000 (51%)]	Train Loss: 0.117801
# Train Epoch: 31 [32000/50000 (64%)]	Train Loss: 0.408481
# Train Epoch: 31 [38400/50000 (77%)]	Train Loss: 0.324975
# Train Epoch: 31 [44800/50000 (90%)]	Train Loss: 0.249347
#
# Epoch: 31
# Test Loss: 0.0108
# Test Accuracy: 89.36
#
# Train Epoch: 32 [0/50000 (0%)]	Train Loss: 0.217330
# Train Epoch: 32 [6400/50000 (13%)]	Train Loss: 0.183757
# Train Epoch: 32 [12800/50000 (26%)]	Train Loss: 0.371856
# Train Epoch: 32 [19200/50000 (38%)]	Train Loss: 0.321032
# Train Epoch: 37 [0/50000 (0%)]	Train Loss: 0.301429
# Train Epoch: 37 [6400/50000 (13%)]	Train Loss: 0.023547
# Train Epoch: 37 [12800/50000 (26%)]	Train Loss: 0.203582
# Train Epoch: 37 [19200/50000 (38%)]	Train Loss: 0.183456
# Train Epoch: 37 [25600/50000 (51%)]	Train Loss: 0.331344
# Train Epoch: 37 [32000/50000 (64%)]	Train Loss: 0.349629
# Train Epoch: 37 [38400/50000 (77%)]	Train Loss: 0.529706
# Train Epoch: 37 [44800/50000 (90%)]	Train Loss: 0.319942
#
# Epoch: 37
# Test Loss: 0.0102
# Test Accuracy: 90.16
#
# Train Epoch: 38 [0/50000 (0%)]	Train Loss: 0.118466
# Train Epoch: 38 [6400/50000 (13%)]	Train Loss: 0.369714
# Train Epoch: 38 [12800/50000 (26%)]	Train Loss: 0.363955
# Train Epoch: 38 [19200/50000 (38%)]	Train Loss: 0.122421
# Train Epoch: 38 [25600/50000 (51%)]	Train Loss: 0.206618
# Train Epoch: 38 [32000/50000 (64%)]	Train Loss: 0.144471
# Train Epoch: 38 [38400/50000 (77%)]	Train Loss: 0.318865
# Train Epoch: 38 [44800/50000 (90%)]	Train Loss: 0.217266
#
# Epoch: 38
# Test Loss: 0.0102
# Test Accuracy: 90.01
#
# Train Epoch: 39 [0/50000 (0%)]	Train Loss: 0.183074
# Train Epoch: 39 [6400/50000 (13%)]	Train Loss: 0.282522
# Train Epoch: 39 [12800/50000 (26%)]	Train Loss: 0.160338
# Train Epoch: 39 [19200/50000 (38%)]	Train Loss: 0.114577
# Train Epoch: 39 [25600/50000 (51%)]	Train Loss: 0.029996
# Train Epoch: 39 [32000/50000 (64%)]	Train Loss: 0.145040
# Train Epoch: 39 [38400/50000 (77%)]	Train Loss: 0.231364
# Train Epoch: 39 [44800/50000 (90%)]	Train Loss: 0.078267
#
# Epoch: 39
# Test Loss: 0.0104
# Test Accuracy: 89.80
#
# Train Epoch: 40 [0/50000 (0%)]	Train Loss: 0.237988
# Train Epoch: 40 [6400/50000 (13%)]	Train Loss: 0.072603
# Train Epoch: 40 [12800/50000 (26%)]	Train Loss: 0.528736
# Train Epoch: 40 [19200/50000 (38%)]	Train Loss: 0.387652
# Train Epoch: 40 [25600/50000 (51%)]	Train Loss: 0.169722
# Train Epoch: 40 [32000/50000 (64%)]	Train Loss: 0.104362
# Train Epoch: 40 [38400/50000 (77%)]	Train Loss: 0.308189
# Train Epoch: 40 [44800/50000 (90%)]	Train Loss: 0.204246
#
# Epoch: 40
# Test Loss: 0.0100
# Test Accuracy: 90.50
#
# Train Epoch: 41 [0/50000 (0%)]	Train Loss: 0.098374
# Train Epoch: 41 [6400/50000 (13%)]	Train Loss: 0.131030
# Train Epoch: 41 [12800/50000 (26%)]	Train Loss: 0.623984
# Train Epoch: 41 [19200/50000 (38%)]	Train Loss: 0.054328
# Train Epoch: 41 [25600/50000 (51%)]	Train Loss: 0.207658
# Train Epoch: 41 [32000/50000 (64%)]	Train Loss: 0.182345
# Train Epoch: 41 [38400/50000 (77%)]	Train Loss: 0.187296
# Train Epoch: 41 [44800/50000 (90%)]	Train Loss: 0.242577
#
# Epoch: 41
# Test Loss: 0.0098
# Test Accuracy: 90.22
#
# Train Epoch: 42 [0/50000 (0%)]	Train Loss: 0.149694
# Train Epoch: 42 [6400/50000 (13%)]	Train Loss: 0.301890
# Train Epoch: 42 [12800/50000 (26%)]	Train Loss: 0.130521
# Train Epoch: 42 [19200/50000 (38%)]	Train Loss: 0.451940
# Train Epoch: 42 [25600/50000 (51%)]	Train Loss: 0.105568
# Train Epoch: 42 [32000/50000 (64%)]	Train Loss: 0.329817
# Train Epoch: 42 [38400/50000 (77%)]	Train Loss: 0.423350
# Train Epoch: 42 [44800/50000 (90%)]	Train Loss: 0.145554
#
# Epoch: 42
# Test Loss: 0.0104
# Test Accuracy: 89.76
#
# Train Epoch: 43 [0/50000 (0%)]	Train Loss: 0.138935
# Train Epoch: 43 [6400/50000 (13%)]	Train Loss: 0.332453
# Train Epoch: 43 [12800/50000 (26%)]	Train Loss: 0.108486
# Train Epoch: 43 [19200/50000 (38%)]	Train Loss: 0.064661
# Train Epoch: 43 [25600/50000 (51%)]	Train Loss: 0.069487
# Train Epoch: 43 [32000/50000 (64%)]	Train Loss: 0.119418
# Train Epoch: 43 [38400/50000 (77%)]	Train Loss: 0.163528
# Train Epoch: 43 [44800/50000 (90%)]	Train Loss: 0.048847
#
# Epoch: 43
# Test Loss: 0.0100
# Test Accuracy: 90.06
#
# Train Epoch: 44 [0/50000 (0%)]	Train Loss: 0.375211
# Train Epoch: 44 [6400/50000 (13%)]	Train Loss: 0.141204
# Train Epoch: 44 [12800/50000 (26%)]	Train Loss: 0.146975
# Train Epoch: 44 [19200/50000 (38%)]	Train Loss: 0.154699
# Train Epoch: 44 [25600/50000 (51%)]	Train Loss: 0.244719
# Train Epoch: 44 [32000/50000 (64%)]	Train Loss: 0.316428
# Train Epoch: 44 [38400/50000 (77%)]	Train Loss: 0.092677
# Train Epoch: 44 [44800/50000 (90%)]	Train Loss: 0.269910
#
# Epoch: 44
# Test Loss: 0.0097
# Test Accuracy: 90.29
#
# Train Epoch: 45 [0/50000 (0%)]	Train Loss: 0.063975
# Train Epoch: 45 [6400/50000 (13%)]	Train Loss: 0.266594
# Train Epoch: 45 [12800/50000 (26%)]	Train Loss: 0.163114
# Train Epoch: 45 [19200/50000 (38%)]	Train Loss: 0.055776
# Train Epoch: 45 [25600/50000 (51%)]	Train Loss: 0.207491
# Train Epoch: 45 [32000/50000 (64%)]	Train Loss: 0.335361
# Train Epoch: 45 [38400/50000 (77%)]	Train Loss: 0.058085
# Train Epoch: 45 [44800/50000 (90%)]	Train Loss: 0.300109
#
# Epoch: 45
# Test Loss: 0.0101
# Test Accuracy: 90.16
#
# Train Epoch: 46 [0/50000 (0%)]	Train Loss: 0.221973
# Train Epoch: 46 [6400/50000 (13%)]	Train Loss: 0.189610
# Train Epoch: 46 [12800/50000 (26%)]	Train Loss: 0.339975
# Train Epoch: 46 [19200/50000 (38%)]	Train Loss: 0.159717
# Train Epoch: 46 [25600/50000 (51%)]	Train Loss: 0.214745
# Train Epoch: 46 [32000/50000 (64%)]	Train Loss: 0.156006
# Train Epoch: 46 [38400/50000 (77%)]	Train Loss: 0.041057
# Train Epoch: 46 [44800/50000 (90%)]	Train Loss: 0.128800
#
# Epoch: 46
# Test Loss: 0.0104
# Test Accuracy: 89.94
#
# Train Epoch: 47 [0/50000 (0%)]	Train Loss: 0.132482
# Train Epoch: 47 [6400/50000 (13%)]	Train Loss: 0.148994
# Train Epoch: 47 [12800/50000 (26%)]	Train Loss: 0.214882
# Train Epoch: 47 [19200/50000 (38%)]	Train Loss: 0.087373
# Train Epoch: 47 [25600/50000 (51%)]	Train Loss: 0.109730
# Train Epoch: 47 [32000/50000 (64%)]	Train Loss: 0.121166
# Train Epoch: 47 [38400/50000 (77%)]	Train Loss: 0.304221
# Train Epoch: 47 [44800/50000 (90%)]	Train Loss: 0.237158
#
# Epoch: 47
# Test Loss: 0.0100
# Test Accuracy: 90.42
#
# Train Epoch: 48 [0/50000 (0%)]	Train Loss: 0.139631
# Train Epoch: 48 [6400/50000 (13%)]	Train Loss: 0.143653
# Train Epoch: 48 [12800/50000 (26%)]	Train Loss: 0.135240
# Train Epoch: 48 [19200/50000 (38%)]	Train Loss: 0.027326
# Train Epoch: 48 [25600/50000 (51%)]	Train Loss: 0.058044
# Train Epoch: 48 [32000/50000 (64%)]	Train Loss: 0.106959
# Train Epoch: 48 [38400/50000 (77%)]	Train Loss: 0.138562
# Train Epoch: 48 [44800/50000 (90%)]	Train Loss: 0.205277
#
# Epoch: 48
# Test Loss: 0.0109
# Test Accuracy: 89.81
#
# Train Epoch: 49 [0/50000 (0%)]	Train Loss: 0.371733
# Train Epoch: 49 [6400/50000 (13%)]	Train Loss: 0.056836
# Train Epoch: 49 [12800/50000 (26%)]	Train Loss: 0.050423
# Train Epoch: 49 [19200/50000 (38%)]	Train Loss: 0.189560
# Train Epoch: 49 [25600/50000 (51%)]	Train Loss: 0.250379
# Train Epoch: 49 [32000/50000 (64%)]	Train Loss: 0.096321
# Train Epoch: 49 [38400/50000 (77%)]	Train Loss: 0.081480
# Train Epoch: 49 [44800/50000 (90%)]	Train Loss: 0.299601
#
# Epoch: 49
# Test Loss: 0.0104
# Test Accuracy: 90.55
#
# Train Epoch: 50 [0/50000 (0%)]	Train Loss: 0.103743
# Train Epoch: 50 [6400/50000 (13%)]	Train Loss: 0.068389
# Train Epoch: 50 [12800/50000 (26%)]	Train Loss: 0.065196
# Train Epoch: 50 [19200/50000 (38%)]	Train Loss: 0.180342
# Train Epoch: 50 [25600/50000 (51%)]	Train Loss: 0.127509
# Train Epoch: 50 [32000/50000 (64%)]	Train Loss: 0.134843
# Train Epoch: 50 [38400/50000 (77%)]	Train Loss: 0.262304
# Train Epoch: 50 [44800/50000 (90%)]	Train Loss: 0.124564
#
# Epoch: 50
# Test Loss: 0.0112
# Test Accuracy: 90.01
